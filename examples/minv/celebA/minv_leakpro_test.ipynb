# %% [markdown]
# ### Test to see what happens with minv-related handlers in leakpro

# %%
import os
import sys
import yaml

# Path to the dataset zip file
data_folder = "./data"

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../.."))
sys.path.append(project_root)

from leakpro import LeakPro
from examples.minv.celebA.celebA_plgmi_handler import CelebA_InputHandler

config_path = "audit.yaml"

leakpro = LeakPro(CelebA_InputHandler, config_path)

results = leakpro.run_audit(return_results=True)
# Out:
# 2025-02-19 08:53:27,883 INFO     Target model blueprint created from ResNet18 in ../../mia/celebA_HQ/utils/celeb_hq_model.py.
# INFO:leakpro:Target model blueprint created from ResNet18 in ../../mia/celebA_HQ/utils/celeb_hq_model.py.
# 2025-02-19 08:53:27,884 INFO     Loaded target model metadata from ./target/model_metadata.pkl
# INFO:leakpro:Loaded target model metadata from ./target/model_metadata.pkl
# Configurations: {'audit': {'random_seed': 1234, 'attack_list': {'plgmi': {'training_data_fraction': 0.5, 'attack_data_fraction': 0.5, 'num_shadow_models': 3, 'online': True, 'temperature': 2, 'gamma': 2.0, 'offline_a': 0.33, 'offline_b': 0.66, 'num_classes': 500}}, 'output_dir': './leakpro_output', 'attack_type': 'minv', 'modality': 'image'}, 'target': {'module_path': '../../mia/celebA_HQ/utils/celeb_hq_model.py', 'model_class': 'ResNet18', 'target_folder': './target', 'data_path': './data/celebaA_data.pkl'}, 'shadow_model': None, 'distillation_model': None, 'generator': {'module_path': './utils/generator.py', 'model_class': 'ResNetGenerator', 'init_params': {'dim_z': 256, 'num_classes': 500, 'bottom_width': 4}}, 'discriminator': {'module_path': './utils/discriminator.py', 'model_class': 'SNResNetProjectionDiscriminator', 'init_params': {'num_classes': 500}}, 'public_dataset': {'public_data_path': './data/celebaA_aux_data.pkl'}}
# 2025-02-19 08:53:28,256 INFO     Loaded target model from ./target
# INFO:leakpro:Loaded target model from ./target
# 2025-02-19 08:53:30,128 INFO     Loaded population dataset from ./data/celebaA_data.pkl
# INFO:leakpro:Loaded population dataset from ./data/celebaA_data.pkl
# 2025-02-19 08:53:30,129 INFO     Loaded population dataset from ./data/celebaA_data.pkl
# INFO:leakpro:Loaded population dataset from ./data/celebaA_data.pkl
# 2025-02-19 08:53:30,449 INFO     MINV attack factory loaded.
# INFO:leakpro:MINV attack factory loaded.
# 2025-02-19 08:53:30,453 INFO     Configuring PLG-MI attack
# INFO:leakpro:Configuring PLG-MI attack
# 2025-02-19 08:53:30,493 INFO     Added attack: plgmi
# INFO:leakpro:Added attack: plgmi
# 2025-02-19 08:53:30,494 INFO     Preparing attack: plgmi
# INFO:leakpro:Preparing attack: plgmi
# 2025-02-19 08:53:30,496 INFO     Preparing attack
# INFO:leakpro:Preparing attack
# 2025-02-19 08:53:30,497 INFO     Setting up generator configurations
# INFO:leakpro:Setting up generator configurations
# 2025-02-19 08:53:30,499 INFO     Generator path: ./utils/generator.py, Generator class: ResNetGenerator
# INFO:leakpro:Generator path: ./utils/generator.py, Generator class: ResNetGenerator
# 2025-02-19 08:53:30,501 INFO     Initialized GeneratorHandler with caller: gan_handler
# INFO:leakpro:Initialized GeneratorHandler with caller: gan_handler
# 2025-02-19 08:53:30,502 INFO     Setting up discriminator configurations
# INFO:leakpro:Setting up discriminator configurations
# 2025-02-19 08:53:31,388 INFO     Loaded public data from ./data/celebaA_aux_data.pkl
# INFO:leakpro:Loaded public data from ./data/celebaA_aux_data.pkl
# 2025-02-19 08:53:31,390 INFO     Performing top-n selection for pseudo labels
# INFO:leakpro:Performing top-n selection for pseudo labels
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 18
#      14 config_path = "audit.yaml"
#      16 leakpro = LeakPro(CelebA_InputHandler, config_path)
# ---> 18 results = leakpro.run_audit(return_results=True)
#
# File ~/LeakPro_fork_hevar/leakpro/leakpro.py:130, in LeakPro.run_audit(self, return_results)
#     128 def run_audit(self:Self, return_results: bool = False) -> None:
#     129     """Run the audit."""
# --> 130     audit_results = self.attack_scheduler.run_attacks()
#     131     results = [] if return_results else None
#     133     for attack_name in audit_results:
#
# File ~/LeakPro_fork_hevar/leakpro/attacks/attack_scheduler.py:84, in AttackScheduler.run_attacks(self)
#      82 for attack, attack_type in zip(self.attacks, self.attack_list):
#      83     logger.info(f"Preparing attack: {attack_type}")
# ---> 84     attack.prepare_attack()
#      86     logger.info(f"Running attack: {attack_type}")
#      88     result = attack.run_attack()
#
# File ~/LeakPro_fork_hevar/leakpro/attacks/minv_attacks/plgmi.py:142, in AttackPLGMI.prepare_attack(self)
#     139 self.public_dataloader = self.gan_handler.get_public_data(self.batch_size)
#     141 # Top-n-selection to get pseudo labels
# --> 142 self.pseudo_loader = self.top_n_selection()
#     144 # Get discriminator
#     145 self.discriminator = self.gan_handler.get_discriminator()
#
# File ~/LeakPro_fork_hevar/leakpro/attacks/minv_attacks/plgmi.py:98, in AttackPLGMI.top_n_selection(self)
#      96 for images, _ in self.public_dataloader:
#      97     with torch.no_grad():
# ---> 98         outputs = self.target_model(images)
#      99         confidences = F.softmax(outputs, dim=1)
#     100         all_confidences.append(confidences)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/LeakPro_fork_hevar/examples/minv/celebA/../../mia/celebA_HQ/utils/celeb_hq_model.py:20, in ResNet18.forward(self, x)
#      19 def forward(self, x):
# ---> 20     return self.model(x)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1845, in Module._call_impl(self, *args, **kwargs)
#    1842     return inner()
#    1844 try:
# -> 1845     return inner()
#    1846 except Exception:
#    1847     # run always called hooks if they have not already been run
#    1848     # For now only forward hooks have the always_call option but perhaps
#    1849     # this functionality should be added to full backward hooks as well.
#    1850     for hook_id, hook in _global_forward_hooks.items():
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1793, in Module._call_impl.<locals>.inner()
#    1790     bw_hook = BackwardHook(self, full_backward_hooks, backward_pre_hooks)
#    1791     args = bw_hook.setup_input_hook(args)
# -> 1793 result = forward_call(*args, **kwargs)
#    1794 if _global_forward_hooks or self._forward_hooks:
#    1795     for hook_id, hook in (
#    1796         *_global_forward_hooks.items(),
#    1797         *self._forward_hooks.items(),
#    1798     ):
#    1799         # mark that always called hook is run
#
# File ~/miniforge3/lib/python3.12/site-packages/torchvision/models/resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File ~/miniforge3/lib/python3.12/site-packages/torchvision/models/resnet.py:275, in ResNet._forward_impl(self, x)
#     273 x = self.layer1(x)
#     274 x = self.layer2(x)
# --> 275 x = self.layer3(x)
#     276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/torchvision/models/resnet.py:92, in BasicBlock.forward(self, x)
#      89 def forward(self, x: Tensor) -> Tensor:
#      90     identity = x
# ---> 92     out = self.conv1(x)
#      93     out = self.bn1(out)
#      94     out = self.relu(out)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
