# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../..")

from leakpro.synthetic_data_attacks.plots import plot_singling_out
from leakpro.synthetic_data_attacks.singling_out_utils import load_singling_out_results

# %% [markdown]
# ## los

# %% [markdown]
# This is the for the case that the released dataset are fully leaked from the training set

# %%
sin_out_res = load_singling_out_results(dataset="los_synthetic_data_1k_original_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %% [markdown]
# This is the for the case that the released dataset are 50% leaked from the training set

# %%
sin_out_res = load_singling_out_results(dataset="los_half_leaked_original_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %% [markdown]
# This is the for the case that the released dataset are 80% leaked from the training set

# %%
sin_out_res = load_singling_out_results(dataset="los_80percentage_leaked_original_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %% [markdown]
# This is the for the case that the released dataset are trained with dpctgan from the training set, with 10k attacks

# %%
sin_out_res = load_singling_out_results(dataset="los_syn_10k_original_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %% [markdown]
# This is the for the case that the released dataset are 50% leaked from the training set, with 20k attacks

# %%
sin_out_res = load_singling_out_results(dataset="los_50percentage_leaked_20k_original_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %% [markdown]
# This is the for the case that the released dataset are 80% leaked from the training set, with 20k attacks

# %%
sin_out_res = load_singling_out_results(dataset="los_80percentage_leaked_20k_original_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %% [markdown]
# ## adults

# %% [markdown]
# This is the for the case that the released dataset are 50% leaked from the training set, with 10k attacks

# %%
sin_out_res = load_singling_out_results(dataset="adults_50percentage_leaked_original_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %% [markdown]
# This is the for the case that the released dataset are 80% leaked from the training set, with 10k attacks

# %%
sin_out_res = load_singling_out_results(dataset="adults_80percentage_leaked_original_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)
