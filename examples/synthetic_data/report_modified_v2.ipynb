# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../..")

from leakpro.synthetic_data_attacks.plots import plot_singling_out
from leakpro.synthetic_data_attacks.singling_out_utils import load_singling_out_results

# %% [markdown]
# ## los

# %%
sin_out_res = load_singling_out_results(dataset="aadults_50percentage_leaked_diverse_modified_report_10k")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %%
sin_out_res = load_singling_out_results(dataset="adults_syn_leaked_diverse_modified_report_20k")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %%
sin_out_res = load_singling_out_results(dataset="los_50percentage_leaked_20k_modified_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %%
sin_out_res = load_singling_out_results(dataset="los_syn_10k_diverse_modified_report")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %%
sin_out_res = load_singling_out_results(dataset="los_syn_10k_diverse_modified_report_v2")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %%
sin_out_res = load_singling_out_results(dataset="los_syn_10k_diverse_modified_report_v3_None")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)

# %%
sin_out_res = load_singling_out_results(dataset="los_syn_10k_diverse_modified_report_v4_None")
plot_singling_out(sin_out_res=sin_out_res, high_res_flag=False)
