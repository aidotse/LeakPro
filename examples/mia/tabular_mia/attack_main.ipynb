# %% [markdown]
# Prepare the dataset and train a model on the data.

# %%
import os
import sys

from data_processing import get_adult_dataset, get_adult_dataloaders
from model import AdultNet, create_trained_model_and_metadata

sys.path.append("../../..")

# Generate the dataset and dataloaders
dataset = get_adult_dataset()
n_features = dataset.x.shape[1]
n_classes = 1
train_loader, test_loader = get_adult_dataloaders(dataset, train_fraction=0.3, test_fraction=0.3)

# Train the model
if not os.path.exists("target"):
    os.makedirs("target")
model = AdultNet(input_size=n_features, hidden_size=64, num_classes=n_classes)
train_acc, train_loss, test_acc, test_loss = create_trained_model_and_metadata(model, 
                                                                               train_loader, 
                                                                               test_loader, 
                                                                               epochs=20)
# Out:
# Directory already exists: data/
# Training Progress: 100%|██████████| 20/20 [00:06<00:00,  3.26it/s]

# %%
import matplotlib.pyplot as plt

# Plot training and test accuracy
plt.figure(figsize=(5, 4))

plt.subplot(1, 2, 1)
plt.plot(train_acc, label='Train Accuracy')
plt.plot(test_acc, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

# Plot training and test loss
plt.subplot(1, 2, 2)
plt.plot(train_loss, label='Train Loss')
plt.plot(test_loss, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Create LeakPro objects and run attack

# %%
from adult_handler import AdultInputHandler

from leakpro import LeakPro

# Read the config file
config_path = "audit.yaml"

# Prepare leakpro object
leakpro = LeakPro(AdultInputHandler, config_path)

# Run the audit
leakpro.run_audit()
# Out:
# 2024-09-09 21:04:01,288 INFO     Target model blueprint created from AdultNet in model.py.
# 2024-09-09 21:04:01,288 INFO     Target model blueprint created from AdultNet in model.py.
# 2024-09-09 21:04:01,288 INFO     Target model blueprint created from AdultNet in model.py.
# 2024-09-09 21:04:01,292 INFO     Loaded target model metadata from ./target/model_metadata.pkl
# 2024-09-09 21:04:01,292 INFO     Loaded target model metadata from ./target/model_metadata.pkl
# 2024-09-09 21:04:01,292 INFO     Loaded target model metadata from ./target/model_metadata.pkl
# 2024-09-09 21:04:01,297 INFO     Loaded target model from ./target
# 2024-09-09 21:04:01,297 INFO     Loaded target model from ./target
# 2024-09-09 21:04:01,297 INFO     Loaded target model from ./target
# 2024-09-09 21:04:01,321 INFO     Loaded population dataset from ./data/adult_data.pkl
# 2024-09-09 21:04:01,321 INFO     Loaded population dataset from ./data/adult_data.pkl
# 2024-09-09 21:04:01,321 INFO     Loaded population dataset from ./data/adult_data.pkl
# 2024-09-09 21:04:01,325 INFO     Loaded population dataset from ./data/adult_data.pkl
# 2024-09-09 21:04:01,325 INFO     Loaded population dataset from ./data/adult_data.pkl
# 2024-09-09 21:04:01,325 INFO     Loaded population dataset from ./data/adult_data.pkl
# 2024-09-09 21:04:01,328 INFO     Creating shadow model handler singleton
# 2024-09-09 21:04:01,328 INFO     Creating shadow model handler singleton
# 2024-09-09 21:04:01,328 INFO     Creating shadow model handler singleton
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       6 config_path = "audit.yaml"
#       8 # Prepare leakpro object
# ----> 9 leakpro = LeakPro(AdultInputHandler, config_path)
#      11 # Run the audit
#      12 leakpro.run_audit()
#
# File ~/project/LeakPro/examples/mia/tabular_mia/../../../leakpro/leakpro.py:38, in LeakPro.__init__(self, handler, configs_path)
#      36 # Initialize handler and attack scheduler
#      37 self.handler = handler(configs, logger)
# ---> 38 self.attack_scheduler = AttackScheduler(self.handler)
#
# File ~/project/LeakPro/examples/mia/tabular_mia/../../../leakpro/attacks/attack_scheduler.py:44, in AttackScheduler.__init__(self, handler)
#      42 for attack_name in self.attack_list:
#      43     try:
# ---> 44         attack = factory.create_attack(attack_name, handler)
#      45         self.add_attack(attack)
#      46         self.logger.info(f"Added attack: {attack_name}")
#
# File ~/project/LeakPro/examples/mia/tabular_mia/../../../leakpro/attacks/mia_attacks/attack_factory_mia.py:52, in AttackFactoryMIA.create_attack(cls, name, handler)
#      50 if AttackFactoryMIA.shadow_model_handler is None:
#      51     handler.logger.info("Creating shadow model handler singleton")
# ---> 52     AttackFactoryMIA.shadow_model_handler = ShadowModelHandler(handler)
#      54 if AttackFactoryMIA.distillation_model_handler is None:
#      55     handler.logger.info("Creating distillation model handler singleton")
#
# File ~/project/LeakPro/examples/mia/tabular_mia/../../../leakpro/attacks/utils/shadow_model_handler.py:27, in singleton.<locals>.get_instance(*args, **kwargs)
#      24 if cls not in instances:
#      25     # Store the initialization parameters when the singleton is first created
#      26     params[cls] = (args, kwargs)
# ---> 27     instances[cls] = cls(*args, **kwargs)  # Create the singleton instance
#      28 elif args or kwargs:
#      29     # Raise an error if trying to reinitialize with different parameters
#      30     raise ValueError("Singleton already created with specific parameters.")
#
# File ~/project/LeakPro/examples/mia/tabular_mia/../../../leakpro/attacks/utils/shadow_model_handler.py:57, in ShadowModelHandler.__init__(self, handler)
#      54 self.configs = handler.configs["shadow_model"]
#      56 # Read from the config file
# ---> 57 module_path = self.configs.get("module_path", None)
#      58 model_class = self.configs.get("model_class", None)
#      59 self.optimizer_config = self.configs.get("optimizer", None)
#
# AttributeError: 'NoneType' object has no attribute 'get'
